# %% [markdown]
# First Request

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{'id': '41983311989',
#   'type': 'WatchEvent',
#   'actor': {'id': 39147652,
#    'login': 'Seagant',
#    'display_login': 'Seagant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Seagant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39147652?'},
#   'repo': {'id': 48576134,
#    'name': 'xifangczy/cat-catch',
#    'url': 'https://api.github.com/repos/xifangczy/cat-catch'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-09-17T00:18:54Z'},
#  {'id': '41983311974',
#   'type': 'PushEvent',
#   'actor': {'id': 2191837,
#    'login': 'chipperdoodles',
#    'display_login': 'chipperdoodles',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chipperdoodles',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2191837?'},
#   'repo': {'id': 858293768,
#    'name': 'chipperdoodles/plappleso',
#    'url': 'https://api.github.com/repos/chipperdoodles/plappleso'},
# ...

# %% [markdown]
# Getting from repo

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_url_base = 'https://api.github.com'
owner = 'amzn' #username
url = f'{api_url_base}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# API Auth

# %%
from AuthToken import TokenProvider

headers = {'Authorization': 'Bearer ' + TokenProvider.TOKEN, 
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# Pagination

# %%
repos_list = []
for page_num in range(1, 6): # get all the pages from amazon repos
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.extend(response.json())
    except:
        repos_list.append(None)

# %%
len(repos_list) # successfuly getting the repos in all pages
# Out:
# 150
